# %%
import pandas_datareader as pdr

# %%
import yfinance as yf

df = yf.download('AAPL', start='2000-01-01', end='2025-01-22')
print(df.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price          Close      High       Low      Open     Volume
# Ticker          AAPL      AAPL      AAPL      AAPL       AAPL
# Date
# 2000-01-03  0.843077  0.847313  0.765877  0.789884  535796800
# 2000-01-04  0.771997  0.833191  0.762111  0.815303  512377600
# 2000-01-05  0.783293  0.832720  0.775762  0.781411  778321600
# 2000-01-06  0.715509  0.805889  0.715509  0.799299  767972800
# 2000-01-07  0.749401  0.760699  0.719275  0.726806  460734400

# %%
df.tail()
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker            AAPL        AAPL        AAPL        AAPL      AAPL
# Date
# 2025-01-14  233.279999  236.119995  232.470001  234.750000  39435300
# 2025-01-15  237.869995  238.960007  234.429993  234.639999  39832000
# 2025-01-16  228.259995  238.009995  228.029999  237.350006  71759100
# 2025-01-17  229.979996  232.289993  228.479996  232.119995  68488300
# 2025-01-21  222.639999  224.419998  219.380005  224.000000  98070400

# %%
df.head()
# Out:
# Price          Close      High       Low      Open     Volume
# Ticker          AAPL      AAPL      AAPL      AAPL       AAPL
# Date
# 2000-01-03  0.843077  0.847313  0.765877  0.789884  535796800
# 2000-01-04  0.771997  0.833191  0.762111  0.815303  512377600
# 2000-01-05  0.783293  0.832720  0.775762  0.781411  778321600
# 2000-01-06  0.715509  0.805889  0.715509  0.799299  767972800
# 2000-01-07  0.749401  0.760699  0.719275  0.726806  460734400

# %%
df.shape
# Out:
# (6301, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6301 entries, 2000-01-03 to 2025-01-21
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (Close, AAPL)   6301 non-null   float64
#  1   (High, AAPL)    6301 non-null   float64
#  2   (Low, AAPL)     6301 non-null   float64
#  3   (Open, AAPL)    6301 non-null   float64
#  4   (Volume, AAPL)  6301 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 295.4 KB

# %%
df.isnull().sum()
# Out:
# Price   Ticker
# Close   AAPL      0
# High    AAPL      0
# Low     AAPL      0
# Open    AAPL      0
# Volume  AAPL      0
# dtype: int64

# %%
df.describe()
# Out:
# Price         Close         High          Low         Open        Volume
# Ticker         AAPL         AAPL         AAPL         AAPL          AAPL
# count   6301.000000  6301.000000  6301.000000  6301.000000  6.301000e+03
# mean      41.664969    42.074898    41.213816    41.634457  3.852885e+08
# std       60.773519    61.345778    60.129968    60.716711  3.836426e+08
# min        0.197631     0.198686     0.191606     0.195673  2.323470e+07
# 25%        2.021803     2.050723     1.986553     2.021501  1.151276e+08
# 50%       13.900799    14.057435    13.779431    13.931675  2.668652e+08
# 75%       44.550304    44.756597    44.137713    44.483909  5.174904e+08
# max      259.019989   260.100006   257.630005   258.190002  7.421641e+09

# %%
df = df.reset_index()

# %%
df.columns
# Out:
# MultiIndex([(  'Date',     ''),
#             ( 'Close', 'AAPL'),
#             (  'High', 'AAPL'),
#             (   'Low', 'AAPL'),
#             (  'Open', 'AAPL'),
#             ('Volume', 'AAPL')],
#            names=['Price', 'Ticker'])

# %%
df.to_csv("Apple.csv")

# %%
import pandas as pd

data01 = pd.read_csv("Apple.csv")
print(data01.head())
# Out:
#     Price        Date               Close                High  \
# 0  Ticker         NaN                AAPL                AAPL
# 1       0  2000-01-03  0.8430765271186829  0.8473128626610195
# 2       1  2000-01-04  0.7719966173171997  0.8331908812665904
# 3       2  2000-01-05  0.7832934856414795  0.8327202824380401
# 4       3  2000-01-06  0.7155086398124695  0.8058888701163703
#
#                   Low                Open     Volume
# 0                AAPL                AAPL       AAPL
# 1   0.765876783368589  0.7898841596356192  535796800
# 2  0.7621110984437448  0.8153034579153242  512377600
# 3  0.7757622951639765  0.7814106754522704  778321600
# 4  0.7155086398124695  0.7992990587471099  767972800

# %%
import plotly.graph_objects as go


fig = go.Figure(data=[go.Candlestick(
    x=data01['Date'],
    open=data01['Open'],
    high=data01['High'],
    low=data01['Low'],
    close=data01['Close']
)])

fig.update_layout(xaxis_rangeslider_visible=False)
fig.show()

# %%
print(df.columns)
if 'Date' in df.columns:
    df = df.drop(['Date'], axis=1)
else:
    print("Column 'Date' not found.")

df = df.drop(['Date'], axis=1, errors='ignore')
# Out:
# MultiIndex([( 'Close', 'AAPL'),
#             (  'High', 'AAPL'),
#             (   'Low', 'AAPL'),
#             (  'Open', 'AAPL'),
#             ('Volume', 'AAPL')],
#            names=['Price', 'Ticker'])
# Column 'Date' not found.

# %%
df.head()
# Out:
# Price      Close      High       Low      Open     Volume
# Ticker      AAPL      AAPL      AAPL      AAPL       AAPL
# 0       0.843077  0.847313  0.765877  0.789884  535796800
# 1       0.771997  0.833191  0.762111  0.815303  512377600
# 2       0.783293  0.832720  0.775762  0.781411  778321600
# 3       0.715509  0.805889  0.715509  0.799299  767972800
# 4       0.749401  0.760699  0.719275  0.726806  460734400

# %%
import matplotlib.pyplot as plt

# %%
stock = "Apple"
plt.figure(figsize=(12, 6))
plt.plot(df['Close'], label=f'{stock} Closing Price', linewidth=1)
plt.title(f'{stock} Closing prices over time')
plt.xlabel('Date')
plt.ylabel(' Closing Price (USD)')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Open'], label=f'{stock} Opening Price', linewidth=1)
plt.title(f'{stock} Opening prices over time')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['High'], label=f'{stock} High Price', linewidth=2)
plt.title(f'{stock} High prices over time')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Volume'], label=f'{stock} volume', linewidth=2)
plt.title(f'{stock} Volume over time')
plt.legend()
plt.show()

# %%
#moving average - to predict next day
#[10, 20, 30, 40, 50, 60, 70, 80, 90]
#moving average for last 5 days -> null null null null 30.0 40.0 50
# 10+20+30+40+50 / 5

temp_data = [10, 20, 30, 40, 50, 60, 70, 80, 90]
print(sum(temp_data[0:5])/5)
# Out:
# 30.0

# %%
import pandas as pd
df01 = pd.DataFrame(temp_data)

# %%
df01.rolling(5).mean()
# Out:
#       0
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4  30.0
# 5  40.0
# 6  50.0
# 7  60.0
# 8  70.0

# %%
ma100 = df.Close.rolling(100).mean()
ma100
# Out:
# Ticker        AAPL
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 6296    232.843892
# 6297    232.961080
# 6298    233.000847
# 6299    233.034740
# 6300    232.991837
#
# [6301 rows x 1 columns]

# %%
ma200 = df.Close.rolling(200).mean()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df.Close, label=f'{stock} Close Price', linewidth=1)
plt.plot(ma100, label=f'{stock} moving average 100 Price', linewidth=1)
plt.plot(ma200, label=f'{stock} moving average 200 Price', linewidth=1)
plt.legend()
plt.show()

# %%
#exponential moving average 
ema100 = df.Close.ewm(span = 100, adjust = False).mean()

# %%
ema200 = df['Close'].ewm(span = 200, adjust = False).mean()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df.Close, label=f'{stock} Close Price', linewidth=1)
plt.plot(ema100, label=f'{stock} Exp. moving average 100 Price', linewidth=1)
plt.plot(ema200, label=f'{stock} Exp. moving average 200 Price', linewidth=1)
plt.legend()
plt.show()

# %%
#LSTM over RNN because lstm is long short term memory can store data in its memory cell, by rnn there is overflow
#divide data for training and testing 

data_training = pd.DataFrame(df['Close'][0:int(len(df)*0.70)])
data_testing = pd.DataFrame(df['Close'][int(len(df)*0.70): int(len(df))])

# %%
data_training.shape
# Out:
# (4410, 1)

# %%
data_testing.shape
# Out:
# (1891, 1)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range = (0, 1))
#data transformed between 0 to 1

# %%
data_training_array = scaler.fit_transform(data_training)

# %%
data_training_array
# Out:
# array([[0.01780519],
#        [0.01584439],
#        [0.01615602],
#        ...,
#        [0.93191751],
#        [0.93327027],
#        [0.94634553]])

# %%
data_training_array.shape[0]
# Out:
# 4410

# %%
import numpy as np

x_train = []
y_train = []

for i in range(100, data_training_array.shape[0]):
    x_train.append(data_training_array[i-100:i])
    y_train.append(data_training_array[i, 0])

x_train, y_train = np.array(x_train), np.array(y_train)

# %%
x_train.shape
# Out:
# (4310, 100, 1)

# %%
from keras.layers import Dense, Dropout, LSTM
from keras.models import Sequential

# %%
model = Sequential()

model.add(LSTM(units = 50, activation = 'relu', return_sequences = True, input_shape = (x_train.shape[1], 1)))
model.add(Dropout(0.2))

model.add(LSTM(units = 60, activation = 'relu', return_sequences = True))
model.add(Dropout(0.3))

model.add(LSTM(units = 80, activation = 'relu', return_sequences = True))
model.add(Dropout(0.4))

model.add(LSTM(units = 120, activation = 'relu'))
model.add(Dropout(0.5))

model.add(Dense(units = 1))
# Out:
# c:\Users\rakes\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 100, 50)        │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 100, 50)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 100, 60)        │        26,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 100, 60)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 100, 80)        │        45,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 100, 80)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 120)            │        96,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 120)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           121 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 178,761 (698.29 KB)
#  Trainable params: 178,761 (698.29 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer = 'adam', loss = 'mean_squared_error')
model.fit(x_train, y_train, epochs = 50)
# Out:
# Epoch 1/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 17s 90ms/step - loss: 0.0039
# Epoch 2/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 12s 89ms/step - loss: 0.0029
# Epoch 3/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 12s 87ms/step - loss: 0.0029
# Epoch 4/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 12s 87ms/step - loss: 0.0026
# Epoch 5/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 12s 87ms/step - loss: 0.0026
# Epoch 6/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 12s 91ms/step - loss: 0.0026
# Epoch 7/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 12s 88ms/step - loss: 0.0023
# Epoch 8/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 12s 88ms/step - loss: 0.0022
# Epoch 9/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 12s 88ms/step - loss: 0.0024
# Epoch 10/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 12s 88ms/step - loss: 0.0022
# Epoch 11/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 12s 89ms/step - loss: 0.0022
# Epoch 12/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 12s 89ms/step - loss: 0.0023
# Epoch 13/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 12s 89ms/step - loss: 0.0021
# Epoch 14/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 12s 90ms/step - loss: 0.0023
# Epoch 15/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 12s 90ms/step - loss: 0.0022
# Epoch 16/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 12s 90ms/step - loss: 0.0020
# Epoch 17/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 12s 90ms/step - loss: 0.0022
# Epoch 18/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 13s 93ms/step - loss: 0.0022
# Epoch 19/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 13s 94ms/step - loss: 0.0019
# Epoch 20/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 14s 100ms/step - loss: 0.0020
# Epoch 21/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 13s 93ms/step - loss: 0.0019
# Epoch 22/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 13s 94ms/step - loss: 0.0020
# Epoch 23/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 13s 99ms/step - loss: 0.0021
# Epoch 24/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 16s 119ms/step - loss: 0.0017
# Epoch 25/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 13s 96ms/step - loss: 0.0020
# Epoch 26/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 13s 97ms/step - loss: 0.0019
# Epoch 27/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 14s 101ms/step - loss: 0.0018
# Epoch 28/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 13s 100ms/step - loss: 0.0019
# Epoch 29/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 13s 96ms/step - loss: 0.0020
# Epoch 30/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 13s 96ms/step - loss: 0.0018
# Epoch 31/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 13s 96ms/step - loss: 0.0019
# Epoch 32/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 13s 99ms/step - loss: 0.0018
# Epoch 33/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 13s 97ms/step - loss: 0.0019
# Epoch 34/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 13s 99ms/step - loss: 0.0022
# Epoch 35/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 13s 98ms/step - loss: 0.0019
# Epoch 36/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 14s 103ms/step - loss: 0.0020
# Epoch 37/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 13s 98ms/step - loss: 0.0023
# Epoch 38/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 13s 99ms/step - loss: 0.0020
# Epoch 39/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 16s 120ms/step - loss: 0.0020
# Epoch 40/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 16s 120ms/step - loss: 0.0019
# Epoch 41/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 16s 120ms/step - loss: 0.0019
# Epoch 42/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 16s 116ms/step - loss: 0.0019
# Epoch 43/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 16s 116ms/step - loss: 0.0019
# Epoch 44/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 16s 118ms/step - loss: 0.0019
# Epoch 45/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 16s 119ms/step - loss: 0.0019
# Epoch 46/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 18s 130ms/step - loss: 0.0021
# Epoch 47/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 17s 125ms/step - loss: 0.0020
# Epoch 48/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 17s 125ms/step - loss: 0.0018
# Epoch 49/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 17s 127ms/step - loss: 0.0019
# Epoch 50/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 17s 125ms/step - loss: 0.0019

# %%
past_100_days = data_training.tail(100)

# %%
import pandas as pd

# Assuming past_100_days and data_testing are DataFrames
final_df = pd.concat([past_100_days, data_testing], ignore_index=True)

# %%
final_df.head()
# Out:
# Ticker       AAPL
# 0       31.787079
# 1       31.882418
# 2       31.747545
# 3       31.777784
# 4       31.840565

# %%
input_data = scaler.fit_transform(final_df)

# %%
x_test = []
y_test = []

for i in range(100, input_data.shape[0]):
    x_test.append(input_data[i-100:i])
    y_test.append(input_data[i, 0])

x_test, y_test  = np.array(x_test), np.array(y_test)

# %%
x_test.shape
# Out:
# (1891, 100, 1)

# %%
y_predicted = model.predict(x_test)
# Out:
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step

# %%
y_predicted.shape
# Out:
# (1891, 1)

# %%
scaler.scale_
# Out:
# array([0.00440001])

# %%
scaler_factor = 1/0.00440001
y_predicted = y_predicted * scaler_factor
y_test = y_test * scaler_factor

# %%
plt.figure(figsize=(12, 6))
plt.plot(y_test, label='Original Price', linewidth=1)
plt.plot(y_predicted, label='Predicted Price', linewidth=1)
plt.legend()
plt.show()

# %%
model.save('stock_dl_model.keras')
